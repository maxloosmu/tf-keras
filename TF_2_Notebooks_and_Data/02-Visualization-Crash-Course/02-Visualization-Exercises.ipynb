# %% [markdown]
# <a href='http://www.pieriandata.com'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Copyright Pierian Data</em></center>
# <center><em>For more information, visit us at <a href='http://www.pieriandata.com'>www.pieriandata.com</a></em></center>

# %% [markdown]
# # Visualization Exercise
#
# ## The Data
#
# This classic dataset contains the prices and other attributes of almost 54,000 diamonds. It's a great dataset for beginners learning to work with data analysis and visualization.
#
# #### Content
#
# * price price in US dollars (\$326--\$18,823)
#
# * carat weight of the diamond (0.2--5.01)
#
# * cut quality of the cut (Fair, Good, Very Good, Premium, Ideal)
#
# * color diamond colour, from J (worst) to D (best)
#
# * clarity a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
#
# * x length in mm (0--10.74)
#
# * y width in mm (0--58.9)
#
# * z depth in mm (0--31.8)
#
# * depth total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)
#
# * table width of top of diamond relative to widest point (43--95)

# %% [markdown]
# ## Imports and Data

# %%
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %%
diamonds = pd.read_csv('../DATA/diamonds.csv')

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %% [markdown]
# #### TASK: Create a scatterplot of price versus carat as shown below

# %%
# CODE HERE
plt.figure(figsize=(8, 5))
plt.scatter(diamonds['carat'], diamonds['price'], alpha=0.5);
plt.title('Scatterplot of Price vs. Carat')
plt.xlabel('Carat')
plt.ylabel('Price')
plt.show()

# %%
sns.scatterplot(data=diamonds, x='carat', y='price', alpha=0.5);

# %% [markdown]
# #### TASK: Use alpha parameter and edgecolor parameter to deal with the overlapping issue and white edgemarker issue.

# %%
plt.scatter(diamonds['carat'], diamonds['price'], alpha=0.5, edgecolor='none')

# %%
# CODE HERE
sns.scatterplot(data=diamonds, x='carat', y='price', alpha=0.5, edgecolor='none')
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %% [markdown]
# #### TASK: Make the previous plot larger

# %%
# CODE HERE

# %% [markdown]
# #### TASK: Create a histogram of the price column as shown below

# %%
# CODE HERE
plt.hist(diamonds['price'], bins=50, color='lightsteelblue', edgecolor='none')
sns.histplot(data=diamonds, x='price', bins=50, color='lightsteelblue', edgecolor='none')
plt.xlim = (0, diamonds['price'].max())
plt.ylim(0)
# Out:
# (0.0, 9444.75)

# %%
# Out:
# (0, 18000)

# %% [markdown]
# #### TASK: Create a count plot of the instances per cut type as shown below

# %%
# CODE HERE
sns.countplot(data=diamonds, x='cut', palette='Set1')
# Out:
# <Axes: xlabel='cut', ylabel='count'>

# %%
custom_palette = {
    'Fair': '#984EA3',
    'Good': '#4DAF4A',
    'Very Good': '#E41A1C',
    'Premium': '#FF7F00',
    'Ideal': '#377EB8'
}
sns.countplot(data=diamonds, x='cut', palette=custom_palette)
# Out:
# <Axes: xlabel='cut', ylabel='count'>

# %% [markdown]
# #### TASK: Create a large box plot figure showing the price distribution per cut type as shown below

# %%
# CODE HERE
plt.figure(figsize=(12, 8))
custom_flierprops = {'marker': 'o', 'markerfacecolor': 'grey', 'markeredgecolor': 'black', 'markersize': 2}
sns.boxplot(data=diamonds, x='cut', y='price', palette=custom_palette, linewidth=1.5, flierprops=custom_flierprops)
# Out:
# <Axes: xlabel='cut', ylabel='price'>

# %% [markdown]
# #### TASK: Challenge! See if you can figure out how to change the ordering of the boxplot as shown below. Feel free to also chaneg the coloring, to reflect this relationship between the cut types.

# %%
# CODE HERE
custom_order = ['Fair', 'Ideal', 'Good', 'Very Good', 'Premium']
sns.boxplot(data=diamonds, x='cut', y='price', palette=custom_palette, linewidth=1.5, flierprops=custom_flierprops,order=custom_order)
# Out:
# <Axes: xlabel='cut', ylabel='price'>
